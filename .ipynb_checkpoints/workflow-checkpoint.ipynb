# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

census = pd.read_csv('../../Week15/census.csv')
census.head()
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
# 3      1007  Alabama     Bibb     22604  12073  10531       2.2   74.5   21.4
# 4      1009  Alabama   Blount     57710  28512  29198       8.6   87.9    1.5
#
#    Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.4  ...   0.5          1.3         1.8         26.5     23986
# 1     0.6  ...   1.0          1.4         3.9         26.4     85953
# 2     0.2  ...   1.8          1.5         1.6         24.1      8597
# 3     0.4  ...   0.6          1.5         0.7         28.8      8294
# 4     0.3  ...   0.9          0.4         2.3         34.9     22189
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# ...

# %%
## Procesos ETL

# %%
census.shape
# Out:
# (3220, 37)

# %%
census.columns
# Out:
# Index(['CensusId', 'State', 'County', 'TotalPop', 'Men', 'Women', 'Hispanic',
#        'White', 'Black', 'Native', 'Asian', 'Pacific', 'Citizen', 'Income',
#        'IncomeErr', 'IncomePerCap', 'IncomePerCapErr', 'Poverty',
#        'ChildPoverty', 'Professional', 'Service', 'Office', 'Construction',
#        'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp',
#        'WorkAtHome', 'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment'],
#       dtype='object')

# %%
census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 37 columns):
# CensusId           3220 non-null int64
# State              3220 non-null object
# County             3220 non-null object
# TotalPop           3220 non-null int64
# Men                3220 non-null int64
# Women              3220 non-null int64
# Hispanic           3220 non-null float64
# White              3220 non-null float64
# Black              3220 non-null float64
# Native             3220 non-null float64
# Asian              3220 non-null float64
# Pacific            3220 non-null float64
# Citizen            3220 non-null int64
# Income             3219 non-null float64
# IncomeErr          3219 non-null float64
# IncomePerCap       3220 non-null int64
# IncomePerCapErr    3220 non-null int64
# Poverty            3220 non-null float64
# ChildPoverty       3219 non-null float64
# Professional       3220 non-null float64
# Service            3220 non-null float64
# ...

# %%
census.dropna(inplace=True)
census.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3218 entries, 0 to 3219
# Data columns (total 37 columns):
# CensusId           3218 non-null int64
# State              3218 non-null object
# County             3218 non-null object
# TotalPop           3218 non-null int64
# Men                3218 non-null int64
# Women              3218 non-null int64
# Hispanic           3218 non-null float64
# White              3218 non-null float64
# Black              3218 non-null float64
# Native             3218 non-null float64
# Asian              3218 non-null float64
# Pacific            3218 non-null float64
# Citizen            3218 non-null int64
# Income             3218 non-null float64
# IncomeErr          3218 non-null float64
# IncomePerCap       3218 non-null int64
# IncomePerCapErr    3218 non-null int64
# Poverty            3218 non-null float64
# ChildPoverty       3218 non-null float64
# Professional       3218 non-null float64
# Service            3218 non-null float64
# ...

# %%
##Vista de Outliers

Rango intercuartil : Distancia entre el cuartil 1 y 3 (-3 sigmas y +3 sigmas)
# Out:
#   File "<ipython-input-8-c3109b4fe5dc>", line 3
#     Rango intercuartil : Distancia entre el cuartil 1 y 3 (-3 sigmas y +3 sigmas)
#                      ^
# SyntaxError: invalid syntax

# %%
plt.figure(figsize=(7,7))
census.boxplot(column=['FamilyWork'])
plt.xticks(rotation=45)
plt.show()

# %%
import numpy as np
q1, q3 = np.percentile(census.FamilyWork,[25,75])
iqr = q3 -q1
upper = q3 +(3*iqr)
lower = q3 - (3*iqr)
print(census[census.FamilyWork < lower])
# Out:
# Empty DataFrame
# Columns: [CensusId, State, County, TotalPop, Men, Women, Hispanic, White, Black, Native, Asian, Pacific, Citizen, Income, IncomeErr, IncomePerCap, IncomePerCapErr, Poverty, ChildPoverty, Professional, Service, Office, Construction, Production, Drive, Carpool, Transit, Walk, OtherTransp, WorkAtHome, MeanCommute, Employed, PrivateWork, PublicWork, SelfEmployed, FamilyWork, Unemployment]
# Index: []
#
# [0 rows x 37 columns]

# %%
census_clean = census.loc[census.FamilyWork<upper].copy()
census_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3020 entries, 0 to 3219
# Data columns (total 37 columns):
# CensusId           3020 non-null int64
# State              3020 non-null object
# County             3020 non-null object
# TotalPop           3020 non-null int64
# Men                3020 non-null int64
# Women              3020 non-null int64
# Hispanic           3020 non-null float64
# White              3020 non-null float64
# Black              3020 non-null float64
# Native             3020 non-null float64
# Asian              3020 non-null float64
# Pacific            3020 non-null float64
# Citizen            3020 non-null int64
# Income             3020 non-null float64
# IncomeErr          3020 non-null float64
# IncomePerCap       3020 non-null int64
# IncomePerCapErr    3020 non-null int64
# Poverty            3020 non-null float64
# ChildPoverty       3020 non-null float64
# Professional       3020 non-null float64
# Service            3020 non-null float64
# ...

# %%
census.shape
# Out:
# (3218, 37)

# %%
pd.plotting.scatter_matrix(census_clean)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000021AE6CA04A8>,
# ...
#         ...,
# ...
#         ...,
# ...
#         ...,
# ...
#        ...,
# ...
#         ...,
# ...
#         ...,
# ...
#         ...,
# ...
#       dtype=object)

# %%
def escala(x):
    return (x/100)

# %%
conversion = ['Hispanic','White','Black','Native','Asian','Pacific','Poverty','Service','Office', 'Construction', 'Production', 'Drive', 'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome', 'Employed', 'PrivateWork', 'PublicWork',]

# %%
n_columnas = [x+'Rate' for x in conversion]
census_clean[n_columnas] = census_clean[conversion].apply(escala)
census_clean.NativeRate.head()
# Out:
# 0    0.004
# 1    0.006
# 2    0.002
# 3    0.004
# 4    0.003
# Name: NativeRate, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler
census_clean['TotalPopScaled'] = MinMaxScaler().fit_transform(census_clean.TotalPop.values.reshape(-1,1))
census_clean.TotalPopScaled.describe()
# Out:
# count    3020.000000
# mean        0.010478
# std         0.032757
# min         0.000000
# 25%         0.001265
# 50%         0.002822
# 75%         0.007227
# max         1.000000
# Name: TotalPopScaled, dtype: float64

# %%
#one-hot encoding
estados = pd.get_dummies(census_clean.State,drop_first = True) #borra el primer dato del dataframe para que no de la diagonal 
# de 1 en la matriz de correlación
census_dummy = pd.concat([census_clean,estados],axis = 1).copy()
census_dummy.columns.values
# Out:
# array(['CensusId', 'State', 'County', 'TotalPop', 'Men', 'Women',
#        'Hispanic', 'White', 'Black', 'Native', 'Asian', 'Pacific',
#        'Citizen', 'Income', 'IncomeErr', 'IncomePerCap',
#        'IncomePerCapErr', 'Poverty', 'ChildPoverty', 'Professional',
#        'Service', 'Office', 'Construction', 'Production', 'Drive',
#        'Carpool', 'Transit', 'Walk', 'OtherTransp', 'WorkAtHome',
#        'MeanCommute', 'Employed', 'PrivateWork', 'PublicWork',
#        'SelfEmployed', 'FamilyWork', 'Unemployment', 'HispanicRate',
#        'WhiteRate', 'BlackRate', 'NativeRate', 'AsianRate', 'PacificRate',
#        'PovertyRate', 'ServiceRate', 'OfficeRate', 'ConstructionRate',
#        'ProductionRate', 'DriveRate', 'CarpoolRate', 'TransitRate',
#        'WalkRate', 'OtherTranspRate', 'WorkAtHomeRate', 'EmployedRate',
#        'PrivateWorkRate', 'PublicWorkRate', 'TotalPopScaled', 'Alaska',
#        'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut',
# ...

# %%
#Suffling: Muestra aleatoria sin reemplazo
s_census = census_dummy.sample(frac = 1)
s_census.head()
# Out:
#       CensusId         State    County  TotalPop    Men  Women  Hispanic  \
# 925      20075        Kansas  Hamilton      2586   1342   1244      33.7
# 976      20177        Kansas   Shawnee    178792  86783  92009      11.5
# 1993     38007  North Dakota  Billings       969    582    387       4.3
# 3095     55095     Wisconsin      Polk     43572  21937  21635       1.7
# 2273     42059  Pennsylvania    Greene     37938  19652  18286       2.3
#
#       White  Black  Native  ...  South Dakota  Tennessee  Texas  Utah  \
# 925    64.7    0.0     0.2  ...             0          0      0     0
# 976    74.8    7.4     0.7  ...             0          0      0     0
# 1993   91.3    0.8     0.5  ...             0          0      0     0
# 3095   95.5    0.4     0.9  ...             0          0      0     0
# 2273   91.2    4.8     0.1  ...             0          0      0     0
#
#       Vermont  Virginia  Washington  West Virginia  Wisconsin  Wyoming
# ...

# %%
census_sample_proporcion = census_dummy.sample(frac=0.5)
census_sample_observation = census_dummy.sample(n = 1000)
print(census_sample_observation.shape,census_sample_proporcion.shape)
# Out:
# (1000, 109) (1510, 109)

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(s_census,test_size=0.2)#Nuestro dataset de prueba es el 20% del dataset completo
print(test.shape,train.shape)
# Out:
# (604, 109) (2416, 109)

# %%
census_modificado = census.copy()

# %%
# Los tipos float se convertirán en un tipo de dato de categoria más baja que float
for e in census_modificado.select_dtypes('float').columns:
    census_modificado[e] = pd.to_numeric(census_modificado[e], downcast = 'float')

# %%
census_modificado.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3218 entries, 0 to 3219
# Data columns (total 37 columns):
# CensusId           3218 non-null int64
# State              3218 non-null object
# County             3218 non-null object
# TotalPop           3218 non-null int64
# Men                3218 non-null int64
# Women              3218 non-null int64
# Hispanic           3218 non-null float32
# White              3218 non-null float32
# Black              3218 non-null float32
# Native             3218 non-null float32
# Asian              3218 non-null float32
# Pacific            3218 non-null float32
# Citizen            3218 non-null int64
# Income             3218 non-null float32
# IncomeErr          3218 non-null float32
# IncomePerCap       3218 non-null int64
# IncomePerCapErr    3218 non-null int64
# Poverty            3218 non-null float32
# ChildPoverty       3218 non-null float32
# Professional       3218 non-null float32
# Service            3218 non-null float32
# ...

# %%
# Mismo tratamiento pero para enteros
for e in census_modificado.select_dtypes('integer').columns:
    census_modificado[e] = pd.to_numeric(census_modificado[e], downcast='integer')
census_modificado.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3218 entries, 0 to 3219
# Data columns (total 37 columns):
# CensusId           3218 non-null int32
# State              3218 non-null object
# County             3218 non-null object
# TotalPop           3218 non-null int32
# Men                3218 non-null int32
# Women              3218 non-null int32
# Hispanic           3218 non-null float32
# White              3218 non-null float32
# Black              3218 non-null float32
# Native             3218 non-null float32
# Asian              3218 non-null float32
# Pacific            3218 non-null float32
# Citizen            3218 non-null int32
# Income             3218 non-null float32
# IncomeErr          3218 non-null float32
# IncomePerCap       3218 non-null int32
# IncomePerCapErr    3218 non-null int16
# Poverty            3218 non-null float32
# ChildPoverty       3218 non-null float32
# Professional       3218 non-null float32
# Service            3218 non-null float32
# ...

# %%
for e in census_modificado.select_dtypes('object').columns:
    census_modificado[e] = census_modificado[e]. astype('category')
census_modificado.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3218 entries, 0 to 3219
# Data columns (total 37 columns):
# CensusId           3218 non-null int32
# State              3218 non-null category
# County             3218 non-null category
# TotalPop           3218 non-null int32
# Men                3218 non-null int32
# Women              3218 non-null int32
# Hispanic           3218 non-null float32
# White              3218 non-null float32
# Black              3218 non-null float32
# Native             3218 non-null float32
# Asian              3218 non-null float32
# Pacific            3218 non-null float32
# Citizen            3218 non-null int32
# Income             3218 non-null float32
# IncomeErr          3218 non-null float32
# IncomePerCap       3218 non-null int32
# IncomePerCapErr    3218 non-null int16
# Poverty            3218 non-null float32
# ChildPoverty       3218 non-null float32
# Professional       3218 non-null float32
# ...

# %%
census['State'].value_counts().sort_values(ascending=False)
# Out:
# Texas                   253
# Georgia                 159
# Virginia                133
# Kentucky                120
# Missouri                115
# Kansas                  105
# Illinois                102
# North Carolina          100
# Iowa                     99
# Tennessee                95
# Nebraska                 93
# Indiana                  92
# Ohio                     88
# Minnesota                87
# Michigan                 83
# Mississippi              82
# Puerto Rico              78
# Oklahoma                 77
# Arkansas                 75
# Wisconsin                72
# Alabama                  67
# Florida                  67
# Pennsylvania             67
# South Dakota             66
# Colorado                 64
# Louisiana                64
# New York                 62
# California               58
# Montana                  56
# West Virginia            55
# North Dakota             53
# South Carolina           46
# Idaho                    44
# ...

# %%
#variable tipo ratio
census['Income'].hist()

# %%
#tip: Se puede checar el tamaño de máximo para definir el tamaño de tipo de dato que se requiere
census['Income'].describe()
# Out:
# count      3218.000000
# mean      46123.616532
# std       12908.429676
# min       10499.000000
# 25%       38191.250000
# 50%       44748.500000
# 75%       52059.000000
# max      123453.000000
# Name: Income, dtype: float64

# %%
x = census['Income']
y = census['Men']/census['TotalPop']

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.scatter(x, y)
plt.show()

# %%
fig = plt.figure(figsize = (15,5))
ax = fig.gca()

census.groupby('State')[['Income']].mean().sort_values('Income',ascending = False).head(30).plot.bar(stacked=False,ax = ax, color = 'darkorange')
ax.set_title('Top 30 States by Salaries')
# Out:
# Text(0.5, 1.0, 'Top 30 States by Salaries')

# %%
fig = plt.figure(figsize = (15,5))
ax = fig.gca()
census.groupby('State')[['Income']].mean().sort_values('Income',ascending = True).head(30).plot.bar(stacked=False,ax = ax, color = 'darkorange')
ax.set_title('Top 30 States by Salaries')
# Out:
# Text(0.5, 1.0, 'Top 30 States by Salaries')

# %%
#### Baseline

# %%
#Obtener los datos numericos de dataframe
df = census._get_numeric_data()
df.head()
# Out:
#    CensusId  TotalPop    Men  Women  Hispanic  White  Black  Native  Asian  \
# 0      1001     55221  26745  28476       2.6   75.8   18.5     0.4    1.0
# 1      1003    195121  95314  99807       4.5   83.1    9.5     0.6    0.7
# 2      1005     26932  14497  12435       4.6   46.2   46.7     0.2    0.4
# 3      1007     22604  12073  10531       2.2   74.5   21.4     0.4    0.1
# 4      1009     57710  28512  29198       8.6   87.9    1.5     0.3    0.1
#
#    Pacific  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0      0.0  ...   0.5          1.3         1.8         26.5     23986
# 1      0.0  ...   1.0          1.4         3.9         26.4     85953
# 2      0.0  ...   1.8          1.5         1.6         24.1      8597
# 3      0.0  ...   0.6          1.5         0.7         28.8      8294
# 4      0.0  ...   0.9          0.4         2.3         34.9     22189
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# ...

# %%
X = df.drop(columns=['TotalPop','CensusId'])
y = df.TotalPop
y.head()
# Out:
# 0     55221
# 1    195121
# 2     26932
# 3     22604
# 4     57710
# Name: TotalPop, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (2574, 33) (2574,)
# (644, 33) (644,)

# %%
from sklearn.preprocessing import scale
x = X.values
x = scale(x); x
# Out:
# array([[-0.14155817, -0.13564947, -0.43691739, ..., -0.62163248,
#         -0.63338261, -0.12090195],
#        [ 0.29602072,  0.30281849, -0.33816171, ..., -0.54497752,
#          0.24544686, -0.14533747],
#        [-0.21971983, -0.23425266, -0.33296405, ..., -0.16170274,
#         -0.41367525,  2.32265078],
#        ...,
#        [-0.23510583, -0.23324456,  4.61001746, ...,  1.32029311,
#         -0.19396788,  4.35079953],
#        [-0.19961145, -0.19616617,  4.61521512, ..., -0.16170274,
#         -0.63338261,  3.9598311 ],
#        [-0.19068361, -0.18512625,  4.59962212, ..., -0.90270066,
#         -0.63338261,  4.64402586]])

# %%
census['TotalPop'].describe()
# Out:
# count    3.218000e+03
# mean     9.947107e+04
# std      3.193951e+05
# min      2.670000e+02
# 25%      1.122525e+04
# 50%      2.607950e+04
# 75%      6.645750e+04
# max      1.003839e+07
# Name: TotalPop, dtype: float64

# %%
from sklearn.decomposition import PCA
covar_matrix = PCA(n_components=30)

# %%
covar_matrix.fit(x)
variance = covar_matrix.explained_variance_ratio_
var = np.cumsum(np.round(covar_matrix.explained_variance_ratio_,decimals=3)*100)

# %%
var
# Out:
# array([ 18.8,  36. ,  49.4,  55.5,  60.8,  65.2,  69. ,  72.3,  75.6,
#         78.7,  81.5,  84. ,  86.3,  88.4,  90.1,  91.7,  93.2,  94.5,
#         95.7,  96.6,  97.5,  98.4,  99.2,  99.7,  99.9, 100. , 100. ,
#        100. , 100. , 100. ])

# %%
plt.ylabel('% Variance Explained')
plt.xlabel('# of Features')
plt.title('PCA Analysis')
plt.ylim(0,110)
plt.style.context('seaborn-whitegrid')
plt.plot(var)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
linreg = LinearRegression(fit_intercept = True, n_jobs=1)
linreg.fit(X_train,y_train)
y_pred = linreg.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 1.0

# %%
#La variación de la variable dependiente se explica completamenta con las variables independientes
#Puede predecir al 100% todas las incidencias en el modelo de prueba

# %%
#¿Qué variables son dependientes y correlacionadas? estas variables nos interesa eliminarlas por que no aportan información nueva
import seaborn as sns
corr = X.corr()
corr
# Out:
#                       Men     Women  Hispanic     White     Black    Native  \
# Men              1.000000  0.999527  0.114408 -0.186933  0.072700 -0.045711
# Women            0.999527  1.000000  0.113588 -0.188642  0.077570 -0.046134
# Hispanic         0.114408  0.113588  1.000000 -0.725294 -0.144421 -0.056771
# White           -0.186933 -0.188642 -0.725294  1.000000 -0.467194 -0.231239
# Black            0.072700  0.077570 -0.144421 -0.467194  1.000000 -0.096943
# Native          -0.045711 -0.046134 -0.056771 -0.231239 -0.096943  1.000000
# Asian            0.453879  0.451372  0.045620 -0.197608  0.021455 -0.001901
# Pacific          0.061245  0.057377  0.004256 -0.094548 -0.049270  0.070116
# Citizen          0.995819  0.996685  0.104220 -0.183615  0.081021 -0.049992
# Income           0.236102  0.234138 -0.219489  0.268055 -0.220398 -0.038544
# IncomeErr       -0.262944 -0.264053 -0.027204  0.084350 -0.082778  0.046761
# ...

# %%
plt.figure(figsize = (12,10))
sns.heatmap(corr,xticklabels=corr.columns.values, yticklabels = corr.columns.values)

# %%
#Separa el dataframe en bins(intervalos) diferentes 
pd.cut(census.Income,3).value_counts()
# Out:
# (10386.046, 48150.333]    1984
# (48150.333, 85801.667]    1193
# (85801.667, 123453.0]       41
# Name: Income, dtype: int64

# %%
# se muestra que los datos están sesgados a la izquierda, y los intervalos usados

# %%
# Es la misma idea de los bins anterior, pero aqui se utilizan los cuartiles como intervalos.
pd.qcut(census.Income,[0,0.25,0.5,0.75,1]).value_counts()
# Out:
# (52059.0, 123453.0]      805
# (10498.999, 38191.25]    805
# (44748.5, 52059.0]       804
# (38191.25, 44748.5]      804
# Name: Income, dtype: int64

# %%
# se crea una columna (boolean) en la que es True si el desempleo es mayor a 0.07 y los ingresos se encuentran en el cuartil 0
census['HighUnemploymentLowIncome'] = np.where((census.Unemployment > 0.07)&(pd.qcut(census.Income,[0,1/3,2/3,1]).cat.codes==0),1,0)
census.head()
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
# 3      1007  Alabama     Bibb     22604  12073  10531       2.2   74.5   21.4
# 4      1009  Alabama   Blount     57710  28512  29198       8.6   87.9    1.5
#
#    Native  ...  OtherTransp  WorkAtHome  MeanCommute  Employed  PrivateWork  \
# 0     0.4  ...          1.3         1.8         26.5     23986         73.6
# 1     0.6  ...          1.4         3.9         26.4     85953         81.5
# 2     0.2  ...          1.5         1.6         24.1      8597         71.8
# 3     0.4  ...          1.5         0.7         28.8      8294         76.8
# 4     0.3  ...          0.4         2.3         34.9     22189         82.0
#
# ...

# %%
census.Income.hist(bins =3)
